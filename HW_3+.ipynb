# %% [markdown]
# **1. Загрузите датасет Wine из встроенных датасетов sklearn.datasets с помощью функции load_wine в переменную data.**

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split

data = load_wine()

# %% [markdown]
# **2. Полученный датасет не является датафреймом. Это структура данных, имеющая ключи аналогично словарю. Просмотрите тип данных этой структуры данных и создайте список data_keys, содержащий ее ключи.**

# %%
print(type(data))
# Out:
# <class 'sklearn.utils.Bunch'>

# %%
data_keys = data["feature_names"]
data_keys
# Out:
# ['alcohol',
#  'malic_acid',
#  'ash',
#  'alcalinity_of_ash',
#  'magnesium',
#  'total_phenols',
#  'flavanoids',
#  'nonflavanoid_phenols',
#  'proanthocyanins',
#  'color_intensity',
#  'hue',
#  'od280/od315_of_diluted_wines',
#  'proline']

# %% [markdown]
# **3. Просмотрите данные, описание и названия признаков в датасете. Описание нужно вывести в виде привычного, аккуратно оформленного текста, без обозначений переноса строки, но с самими переносами и т.д.**
#
# **4. Сколько классов содержит целевая переменная датасета? Выве
# дите названия классов.**

# %%
print(data["DESCR"])
# Out:
# .. _wine_dataset:
#
# Wine recognition dataset
# ------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 178 (50 in each of three classes)
#     :Number of Attributes: 13 numeric, predictive attributes and the class
#     :Attribute Information:
#  		- Alcohol
#  		- Malic acid
#  		- Ash
# 		- Alcalinity of ash
#  		- Magnesium
# 		- Total phenols
#  		- Flavanoids
#  		- Nonflavanoid phenols
#  		- Proanthocyanins
# 		- Color intensity
#  		- Hue
#  		- OD280/OD315 of diluted wines
#  		- Proline
#
#     - class:
#             - class_0
#             - class_1
#             - class_2
#
#     :Summary Statistics:
#
#     ============================= ==== ===== ======= =====
#                                    Min   Max   Mean     SD
#     ============================= ==== ===== ======= =====
#     Alcohol:                      11.0  14.8    13.0   0.8
#     Malic Acid:                   0.74  5.80    2.34  1.12
#     Ash:                          1.36  3.23    2.36  0.27
#     Alcalinity of Ash:            10.6  30.0    19.5   3.3
#     Magnesium:                    70.0 162.0    99.7  14.3
#     Total Phenols:                0.98  3.88    2.29  0.63
#     Flavanoids:                   0.34  5.08    2.03  1.00
#     Nonflavanoid Phenols:         0.13  0.66    0.36  0.12
#     Proanthocyanins:              0.41  3.58    1.59  0.57
#     Colour Intensity:              1.3  13.0     5.1   2.3
#     Hue:                          0.48  1.71    0.96  0.23
#     OD280/OD315 of diluted wines: 1.27  4.00    2.61  0.71
#     Proline:                       278  1680     746   315
#     ============================= ==== ===== ======= =====
#
#     :Missing Attribute Values: None
#     :Class Distribution: class_0 (59), class_1 (71), class_2 (48)
#     :Creator: R.A. Fisher
#     :Donor: Michael Marshall (MARSHALL%PLU@io.arc.nasa.gov)
#     :Date: July, 1988
#
# This is a copy of UCI ML Wine recognition datasets.
# https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data
#
# The data is the results of a chemical analysis of wines grown in the same
# region in Italy by three different cultivators. There are thirteen different
# measurements taken for different constituents found in the three types of
# wine.
#
# Original Owners:
#
# Forina, M. et al, PARVUS -
# An Extendible Package for Data Exploration, Classification and Correlation.
# Institute of Pharmaceutical and Food Analysis and Technologies,
# Via Brigata Salerno, 16147 Genoa, Italy.
#
# Citation:
#
# Lichman, M. (2013). UCI Machine Learning Repository
# [https://archive.ics.uci.edu/ml]. Irvine, CA: University of California,
# School of Information and Computer Science.
#
# .. topic:: References
#
#   (1) S. Aeberhard, D. Coomans and O. de Vel,
#   Comparison of Classifiers in High Dimensional Settings,
#   Tech. Rep. no. 92-02, (1992), Dept. of Computer Science and Dept. of
#   Mathematics and Statistics, James Cook University of North Queensland.
#   (Also submitted to Technometrics).
#
#   The data was used with many others for comparing various
#   classifiers. The classes are separable, though only RDA
#   has achieved 100% correct classification.
#   (RDA : 100%, QDA 99.4%, LDA 98.9%, 1NN 96.1% (z-transformed data))
#   (All results using the leave-one-out technique)
#
#   (2) S. Aeberhard, D. Coomans and O. de Vel,
#   "THE CLASSIFICATION PERFORMANCE OF RDA"
#   Tech. Rep. no. 92-01, (1992), Dept. of Computer Science and Dept. of
#   Mathematics and Statistics, James Cook University of North Queensland.
#   (Also submitted to Journal of Chemometrics).

# %%
print(data["target_names"])
# Out:
# ['class_0' 'class_1' 'class_2']

# %% [markdown]
# **5. На основе данных датасета (они содержатся в двумерном массиве Numpy) и названий признаков создайте датафрейм под названием X**

# %%
X = pd.DataFrame(data["data"], columns = data_keys)

# %% [markdown]
# **6. Выясните размер датафрейма X и установите, имеются ли в нем пропущенные значения.**

# %%
X.shape
#(178, 13)
X.isnull().values.any()
#False - не имеются
# Out:
# False

# %% [markdown]
# **7.Добавьте в датафрейм поле с классами вин в виде чисел, имеющих тип данных numpy.int64. Название поля - 'target'.**

# %%
X['target'] = data['target']
#type(data['target'][0]) - numpy.int32 - это какой-то другой target?

# %% [markdown]
# **8. Постройте матрицу корреляций для всех полей X. Дайте полученному датафрейму название X_corr.**

# %%
corr = X.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_a70f9_row0_col0,#T_a70f9_row1_col1,#T_a70f9_row2_col2,#T_a70f9_row3_col3,#T_a70f9_row4_col4,#T_a70f9_row5_col5,#T_a70f9_row6_col6,#T_a70f9_row7_col7,#T_a70f9_row8_col8,#T_a70f9_row9_col9,#T_a70f9_row10_col10,#T_a70f9_row11_col11,#T_a70f9_row12_col12,#T_a70f9_row13_col13{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_a70f9_row0_col1,#T_a70f9_row0_col4{
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }#T_a70f9_row0_col2,#T_a70f9_row3_col6{
#             background-color:  #93b5fe;
#             color:  #000000;
#         }#T_a70f9_row0_col3{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_a70f9_row0_col5,#T_a70f9_row0_col6{
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }#T_a70f9_row0_col7,#T_a70f9_row4_col3,#T_a70f9_row10_col4{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_a70f9_row0_col8,#T_a70f9_row6_col0{
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }#T_a70f9_row0_col9{
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }#T_a70f9_row0_col10,#T_a70f9_row2_col8,#T_a70f9_row4_col2{
#             background-color:  #abc8fd;
#             color:  #000000;
#         }#T_a70f9_row0_col11,#T_a70f9_row3_col2{
#             background-color:  #d8dce2;
#             color:  #000000;
#         }#T_a70f9_row0_col12{
#             background-color:  #f08b6e;
#             color:  #000000;
#         }#T_a70f9_row0_col13,#T_a70f9_row12_col2{
#             background-color:  #97b8ff;
#             color:  #000000;
#         }#T_a70f9_row1_col0,#T_a70f9_row9_col3{
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }#T_a70f9_row1_col2,#T_a70f9_row7_col10{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_a70f9_row1_col3,#T_a70f9_row1_col9{
#             background-color:  #dedcdb;
#             color:  #000000;
#         }#T_a70f9_row1_col4{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_a70f9_row1_col5{
#             background-color:  #84a7fc;
#             color:  #000000;
#         }#T_a70f9_row1_col6,#T_a70f9_row1_col11,#T_a70f9_row12_col1{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_a70f9_row1_col7{
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }#T_a70f9_row1_col8{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_a70f9_row1_col10,#T_a70f9_row11_col13{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_a70f9_row1_col12{
#             background-color:  #94b6ff;
#             color:  #000000;
#         }#T_a70f9_row1_col13{
#             background-color:  #f7ad90;
#             color:  #000000;
#         }#T_a70f9_row2_col0{
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }#T_a70f9_row2_col1,#T_a70f9_row5_col0{
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }#T_a70f9_row2_col3,#T_a70f9_row12_col11{
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }#T_a70f9_row2_col4,#T_a70f9_row2_col13{
#             background-color:  #cad8ef;
#             color:  #000000;
#         }#T_a70f9_row2_col5{
#             background-color:  #dbdcde;
#             color:  #000000;
#         }#T_a70f9_row2_col6{
#             background-color:  #e2dad5;
#             color:  #000000;
#         }#T_a70f9_row2_col7{
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }#T_a70f9_row2_col9{
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }#T_a70f9_row2_col10{
#             background-color:  #aac7fd;
#             color:  #000000;
#         }#T_a70f9_row2_col11{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_a70f9_row2_col12{
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }#T_a70f9_row3_col0{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_a70f9_row3_col1,#T_a70f9_row4_col5{
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }#T_a70f9_row3_col4{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_a70f9_row3_col5{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_a70f9_row3_col7{
#             background-color:  #efcebd;
#             color:  #000000;
#         }#T_a70f9_row3_col8,#T_a70f9_row9_col11{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_a70f9_row3_col9{
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }#T_a70f9_row3_col10{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_a70f9_row3_col11{
#             background-color:  #9abbff;
#             color:  #000000;
#         }#T_a70f9_row3_col12{
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }#T_a70f9_row3_col13,#T_a70f9_row5_col8{
#             background-color:  #f59d7e;
#             color:  #000000;
#         }#T_a70f9_row4_col0{
#             background-color:  #cfdaea;
#             color:  #000000;
#         }#T_a70f9_row4_col1,#T_a70f9_row8_col9{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }#T_a70f9_row4_col6,#T_a70f9_row8_col10{
#             background-color:  #ecd3c5;
#             color:  #000000;
#         }#T_a70f9_row4_col7{
#             background-color:  #7597f6;
#             color:  #000000;
#         }#T_a70f9_row4_col8{
#             background-color:  #dadce0;
#             color:  #000000;
#         }#T_a70f9_row4_col9{
#             background-color:  #d6dce4;
#             color:  #000000;
#         }#T_a70f9_row4_col10{
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }#T_a70f9_row4_col11{
#             background-color:  #d7dce3;
#             color:  #000000;
#         }#T_a70f9_row4_col12{
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }#T_a70f9_row4_col13{
#             background-color:  #aec9fc;
#             color:  #000000;
#         }#T_a70f9_row5_col1,#T_a70f9_row12_col7{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_a70f9_row5_col2,#T_a70f9_row8_col13{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_a70f9_row5_col3{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_a70f9_row5_col4{
#             background-color:  #b7cff9;
#             color:  #000000;
#         }#T_a70f9_row5_col6{
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }#T_a70f9_row5_col7{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_a70f9_row5_col9{
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }#T_a70f9_row5_col10{
#             background-color:  #f6bda2;
#             color:  #000000;
#         }#T_a70f9_row5_col11{
#             background-color:  #e7745b;
#             color:  #000000;
#         }#T_a70f9_row5_col12{
#             background-color:  #f7af91;
#             color:  #000000;
#         }#T_a70f9_row5_col13{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_a70f9_row6_col1{
#             background-color:  #5875e1;
#             color:  #000000;
#         }#T_a70f9_row6_col2,#T_a70f9_row10_col7{
#             background-color:  #7396f5;
#             color:  #000000;
#         }#T_a70f9_row6_col3,#T_a70f9_row9_col10,#T_a70f9_row11_col9{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_a70f9_row6_col4,#T_a70f9_row9_col4{
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }#T_a70f9_row6_col5{
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }#T_a70f9_row6_col7,#T_a70f9_row6_col13,#T_a70f9_row7_col4,#T_a70f9_row10_col1,#T_a70f9_row10_col2,#T_a70f9_row10_col9,#T_a70f9_row12_col3,#T_a70f9_row13

# %% [markdown]
# **9. Создайте список high_corr из признаков, корреляция которых с полем target по абсолютному значению превышает 0.5 (причем, само поле target не должно входить в этот список).**

# %%
inds = np.where(abs(corr.loc['target']) > 0.5)
a = inds[0].tolist()
high_corr = [data_keys[i-1] for i in a]

# %% [markdown]
# **10. Удалите из датафрейма X поле с целевой переменной. Для всех признаков, названия которых содержатся в списке high_corr, вычислите квадрат их значений и добавьте в датафрейм X соответствующие поля с суффиксом '_2', добавленного к первоначальному названию признака. Итоговый датафрейм должен содержать все поля, которые, были в нем изначально, а также поля с признаками из списка high_corr, возведенными в квадрат. Выведите описание полей датафрейма X с помощью метода describe.**

# %%
X.drop(['target'], axis = 1)
for i in high_corr:
    name = i + '_2'
    X[name] = X[i] ** 2

X.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# min         0.980000    0.340000              0.130000         0.410000
# 25%         1.742500    1.205000              0.270000         1.250000
# 50%         2.355000    2.135000              0.340000         1.555000
# 75%         2.800000    2.875000              0.437500         1.950000
# max         3.880000    5.080000              0.660000         3.580000
#
#        color_intensity  ...  od280/od315_of_diluted_wines      proline  \
# count       178.000000  ...                    178.000000   178.000000
# mean          5.058090  ...                      2.611685   746.893258
# std           2.318286  ...                      0.709990   314.907474
# min           1.280000  ...                      1.270000   278.000000
# 25%           3.220000  ...                      1.937500   500.500000
# 50%           4.690000  ...                      2.780000   673.500000
# 75%           6.200000  ...                      3.170000   985.000000
# max          13.000000  ...                      4.000000  1680.000000
#
#            target       ash_2   magnesium_2  total_phenols_2  \
# count  178.000000  178.000000    178.000000       178.000000
# mean     0.938202    5.675244  10151.224719         5.657030
# std      0.775035    1.291991   3089.606212         2.936294
# min      0.000000    1.849600   4900.000000         0.960400
# 25%      0.000000    4.884100   7744.000000         3.036325
# 50%      1.000000    5.569600   9604.000000         5.546050
# 75%      2.000000    6.540825  11449.000000         7.840000
# max      2.000000   10.432900  26244.000000        15.054400
#
#        color_intensity_2       hue_2  od280/od315_of_diluted_wines_2  \
# count         178.000000  178.000000                      178.000000
# mean           30.928529    0.968661                        7.322155
# std            28.872785    0.443798                        3.584316
# min             1.638400    0.230400                        1.612900
# 25%            10.368700    0.612325                        3.754075
# 50%            21.996200    0.931250                        7.728400
# 75%            38.440000    1.254400                       10.048900
# max           169.000000    2.924100                       16.000000
#
#           proline_2
# count  1.780000e+02
# mean   6.564591e+05
# std    5.558591e+05
# min    7.728400e+04
# 25%    2.505010e+05
# 50%    4.536045e+05
# 75%    9.702250e+05
# max    2.822400e+06
#
# [8 rows x 21 columns]
